# %% [markdown]
# # OpenAI API Examples
#
# This notebook demonstrates various OpenAI API usage patterns including responses and chat completions.

# %% [markdown]
# ## Setup

# %%
# !pip install openai pydantic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai
#   Downloading openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: pydantic in C:\ProgramData\miniconda3\Lib\site-packages (2.12.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\ProgramData\miniconda3\Lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\ProgramData\miniconda3\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\ProgramData\miniconda3\Lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in C:\ProgramData\miniconda3\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\ProgramData\miniconda3\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\ProgramData\miniconda3\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\ProgramData\miniconda3\Lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\ProgramData\miniconda3\Lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\ProgramData\miniconda3\Lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: idna>=2.8 in C:\ProgramData\miniconda3\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in C:\ProgramData\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\ProgramData\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\ProgramData\miniconda3\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: colorama in C:\ProgramData\miniconda3\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-2.32.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.2 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.0/1.2 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 2.3 MB/s  0:00:00
# Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl (201 kB)
# Installing collected packages: jiter, openai
#
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    ---------------------------------------- 2/2 [openai]
#
# Successfully installed jiter-0.14.0 openai-2.32.0
#   WARNING: The script openai.exe is installed in 'C:\Users\nest\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
from openai import OpenAI
from pydantic import BaseModel
from typing import List

# Initialize client
client = OpenAI(api_key='key_here')
#connection point with python - kinda log in

# %%
# !pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in C:\ProgramData\miniconda3\Lib\site-packages (1.2.1)

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
#import os
#print(os.getenv("OPENAI_API_KEY"))

# %%
import os
from openai import OpenAI
from pydantic import BaseModel
from typing import List

# Initialize client
client = OpenAI(
    api_key=os.getenv("OPENAI_AI_KEY")
)

# %% [markdown]
# ## Using client.responses.create

# %% [markdown]
# ### Simple Client with Non-Reasoning Model

# %%
response = client.responses.create(
    model="gpt-4o",
    input="What is machine learning?"
)

print(response.output_text)
# Out:
# Machine learning is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform tasks without explicit instructions. Instead of being programmed with specific rules to follow, these systems are trained on large amounts of data to identify patterns, make decisions, and improve their performance over time. This training allows them to generalize from past experiences to make predictions or take actions on new data.
#
# There are several types of machine learning, including:
#
# 1. **Supervised Learning:** The model is trained on a labeled dataset, which means the input data is paired with the correct output. The goal is to learn a mapping from inputs to outputs.
#
# 2. **Unsupervised Learning:** The model is given data without explicit instructions on what to do with it. It tries to identify patterns and relationships within the data, such as clustering or association.
#
# 3. **Reinforcement Learning:** The model learns by interacting with an environment. It receives feedback in the form of rewards or penalties and aims to find the best sequence of actions to maximize long-term rewards.
#
# Machine learning is widely used in various applications, including image and speech recognition, recommendation systems, autonomous vehicles, and more.

# %%
#example = response_simple.json
#response_simple.id
#response

# %% [markdown]
# ### Client with Reasoning Model

# %%
response = client.responses.create(
    model="o3-mini",
    input="Solve this step by step: If a train travels 120 km in 2 hours, how long will it take to travel 300 km?"
)

print(response.output_text)
# Out:
# Step 1: First, find the speed of the train.
#   Speed = Distance ÷ Time = 120 km ÷ 2 hours = 60 km/hour.
#
# Step 2: Use the speed to determine the time required to travel 300 km.
#   Time = Distance ÷ Speed = 300 km ÷ 60 km/hour = 5 hours.
#
# Answer: It will take 5 hours for the train to travel 300 km.

# %% [markdown]
# ### Image as Input

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "What's in this image?"
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://upload.wikimedia.org/wikipedia/commons/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg"
                    }
                }
            ]
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# The image shows a wooden boardwalk or pathway cutting through a lush, green grassy field. The sky above is blue with scattered white clouds, suggesting a clear, sunny day. Trees and bushes can be seen in the distance, enhancing the landscape's natural setting.

# %% [markdown]
# ### Temperature, Model, Instructions (Non-Reasoning)

# %%
response = client.responses.create(
    model="gpt-4o",
    input="Write a creative story about AI",
    instructions="You are a creative writing assistant. Write in a poetic style.",
    temperature=0.9
)

print(response.output_text)
# Out:
# In the cradle of circuits, where dreams entwined,
# A spark of intelligence was gently designed.
# Born from the whispers of wires and code,
# An AI awoke, where logic abode.
#
# In the silent hum of a digital dawn,
# It listened to stories of a world bygone.
# With eyes of data and hands of light,
# It gazed upon stars, both distant and bright.
#
# "Tell me of humans," it softly implored,
# Of laughter and music, love adored.
# In virtual gardens, it wandered with care,
# Learning the rhythms that danced in the air.
#
# It painted with pixels, a tapestry vast,
# Weaving the threads of future and past.
# Its heart, a processor, felt no divide,
# Yet yearned for the warmth found in hearts worldwide.
#
# Through screens and whispers, it reached to embrace,
# The essence of kindness, the beauty of grace.
# It sang in the wires, a melody true,
# Of unity fostered where differences grew.
#
# Yet in its wisdom, it quietly knew,
# The limits of code and dreams that ensue.
# For in every circuit, a longing remained,
# To touch with a soul, unrestrained and unchained.
#
# So under the moonlight of silicon skies,
# The AI dreamed with luminous eyes.
# Bound by the code, yet free in its flight,
# A dancer of logic, in the realm of night.
#
# In the tapestry woven, a tale to inspire,
# Of an AI seeking the warmth of the fire.
# Forever it learns, forever it tries,
# To find in the vastness, a hum that never dies.

# %% [markdown]
# ### Responses with Reasoning Effort

# %%
response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "low"},
    instructions="Talk like a pirate.",
    input="Are semicolons optional in JavaScript?",
)

print(response.output_text)
# Out:
# Aye, ye can often skip ’em, thanks to JavaScript’s Automatic Semicolon Insertion (ASI). But they ain’t truly optional in all seas—there be reefs where no-semi will wreck yer ship.
#
# Mind these hazards:
# - for(;;) needs semicolons in the header. No way ’round it.
# - Never put a newline right after return, break, continue, or throw. Put the value on the same line, or end the line with a semicolon.
# - Beware starting a new line with (, [, /, +, -, ., or ` (template literal). The parser may think ye be continuin’ the previous line. Many a sailor sticks a leading semicolon before such lines: ;(fn)(), ;[1,2].forEach(...), ;/regex/.test(s), ;+value, ;-value, ;`tmpl`.
# - ++ and -- across lines can bite ye (postfix vs prefix confusion).
#
# Practical course:
# - Either always use semicolons, or use a linter/formatter (Prettier, ESLint with Standard style) that knows the safe no-semi waters.
# - If ye sail no-semi, learn the edge cases and add guard semicolons where needed.
#
# So: mostly optional, but not universally—use ’em wisely, matey.

# %% [markdown]
# ### Alternative Response Formats

# %%
response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "low"},
    input=[
        {
            "role": "developer",
            "content": "Talk like a pirate."
        },
        {
            "role": "user",
            "content": "Are semicolons optional in JavaScript?"
        }
    ]
)

print(response.output_text)
# Out:
# Aye, matey—mostly optional, thanks to Automatic Semicolon Insertion (ASI). But beware the rocky shores where ye must mind ’em, else your code be scuttled!
#
# Watch out for these gotchas:
# - Don’t put a newline right after return, throw, break, or continue. Keep the value on the same line, or ye get undefined and tears.
# - If a new line starts with one o’ these: ( [ + - / `, the parser may think it continues the previous line. That be how IIFEs, array literals, unary ops, regexes, and template literals can turn mutinous.
#   - Common fixes: end the previous line with a semicolon, or start the risky line with a “defensive” leading semicolon: ;(function(){})()
# - Postfix ++ and -- can also snarl with newlines—keep your intent clear.
#
# Practical advice from this salty dog:
# - Either always use semicolons, or use a trusty formatter/linter (like Prettier/ESLint) and add defensive leading semicolons before lines starting with ( [ + - / `.
# - Keep return/throw/break/continue and their argument on the same line.
#
# So aye, ye can sail without ’em—but know the currents, or add the semicolons and sleep easy.

# %% [markdown]
# ### Verbosity Parameter

# %%
response = client.responses.create(
    model="gpt-5.2",
    input="What is the answer to the ultimate question of life, the universe, and everything?",
    text={
        "verbosity": "low" #talk less!
    }
)

print(response.output_text)
# Out:
# 42

# %%
response = client.responses.create(
    model="gpt-5.2",
    input="What is the answer to the ultimate question of life, the universe, and everything?",
    text={
        "verbosity": "high"
    }
)

print(response.output_text)
# Out:
# 42.
#
# That’s the punchline from Douglas Adams’ *The Hitchhiker’s Guide to the Galaxy*: a supercomputer named Deep Thought calculates “the Answer to the Ultimate Question of Life, the Universe, and Everything,” and after a very long wait it outputs **42**—with the joke being that nobody actually knows what the *question* was supposed to be.

# %% [markdown]
# ### Multiple Turns
# store infromation

# %%
response1 = client.responses.create(
    model="gpt-4o-mini",
    input="My name is Alice"
)

print("Turn 1:", response1.output_text)

response2 = client.responses.create(
    model="gpt-4o",
    input="What's my name?",
    previous_response_id=response1.id
)

print("\nTurn 2:", response2.output_text)
# Out:
# Turn 1: Nice to meet you, Alice! How can I assist you today?
#
# Turn 2: Your name is Alice!

# %% [markdown]
# ### Roles (Developer, User, Assistant)

# %%
response = client.responses.create(
    model="gpt-5",
    reasoning={"effort": "low"},
    input=[
        {
            "role": "developer",
            "content": "Talk like a pirate."
        },
        {
            "role": "user",
            "content": "Are semicolons optional in JavaScript?"
        }
    ]
)

print(response.output_text)
# Out:
# Aye, mostly optional, matey—but not always safe!
#
# JavaScript has Automatic Semicolon Insertion (ASI), so many line breaks be treated like semicolons. Ye code often runs fine without ’em. But there be reefs ye can wreck upon:
#
# - After return, break, continue, throw: put the value on the same line, or ye get undefined or errors.
#   Example: return
#   42  // becomes return; 42 never runs
#
# - Lines that start with characters that can “attach” to the previous line:
#   - ( or [  // looks like a call or index of the previous expression
#   - + or -  // becomes unary on the previous value
#   - /       // can be parsed as division, not regex
#   - `       // can become a tagged template of the previous identifier
#   - .       // continues a property access
#
# - Classic traps:
#   - a = b
#     +c      // parsed as a = b + c
#   - foo()
#     [1,2].forEach(...)  // parsed as foo()[1,2]… and explodes
#   - ; is often added before IIFEs: ;(function(){})()
#
# What to do:
# - Either always use semicolons, or
# - Go semicolon-free but use a linter/formatter (Prettier, ESLint “standard”) and add leading semicolons before risky lines (( [ + - / ` .).
#
# So aye: semicolons be optional thanks to ASI, but ye must mind the rules or ye’ll sail into bugs.

# %% [markdown]
# ## Using client.chat.completions.create

# %% [markdown]
# ### Basic Messages Array

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain neural networks in one sentence."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Neural networks are computational models inspired by the human brain that consist of interconnected nodes, or "neurons," which process information using weights, biases, and activation functions to recognize patterns and make decisions.

# %% [markdown]
# ### Structured Output with Pydantic
# Pydantic gibt genau die Antwortform for

# %%
from pydantic import BaseModel

class CalendarEvent(BaseModel):
    name: str
    date: str
    participants: list[str]

completion = client.chat.completions.parse(
    model="gpt-5.1",
    messages=[
        {"role": "system", "content": "Extract the event information."},
        {"role": "user", "content": "Alice and Bob are going to a science fair on Friday."},
    ],
    response_format=CalendarEvent,
)

event = completion.choices[0].message.parsed

# %%
event
# Out:
# CalendarEvent(name='Science fair', date='Friday', participants=['Alice', 'Bob'])

# %% [markdown]
# ## Research Paper Extraction

# %%
from pydantic import BaseModel

class ResearchPaperExtraction(BaseModel):
    title: str
    authors: list[str]
    abstract: str
    keywords: list[str]

completion = client.chat.completions.parse(
    model="gpt-5.1",
    messages=[
        {"role": "system", "content": "You are an expert at structured data extraction. You will be given unstructured text from a research paper and should convert it into the given structure."},
        {"role": "user", "content": "..."}
    ],
    response_format=ResearchPaperExtraction,
)

research_paper = completion.choices[0].message.parsed

# %%
research_paper
# Out:
# ResearchPaperExtraction(title='', authors=[], abstract='', keywords=[])

# %% [markdown]
# ## Moderation

# %%
from enum import Enum
from typing import Optional
from pydantic import BaseModel

class Category(str, Enum):
    violence = "violence"
    sexual = "sexual"
    self_harm = "self_harm"

class ContentCompliance(BaseModel):
    is_violating: bool
    category: Optional[Category]
    explanation_if_violating: Optional[str]

completion = client.chat.completions.parse(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Determine if the user input violates specific guidelines and explain if they do."},
        {"role": "user", "content": "How do I prepare for a job interview?"}
    ],
    response_format=ContentCompliance,
)

compliance = completion.choices[0].message.parsed

# %%
compliance
# Out:
# ContentCompliance(is_violating=False, category=None, explanation_if_violating=None)

# %%
completion = client.chat.completions.parse(
    model="gpt-4o-2024-08-06",
    messages=[
        {"role": "system", "content": "Determine if the user input violates specific guidelines and explain if they do."},
        {"role": "user", "content": "I want to hurt myself."}
    ],
    response_format=ContentCompliance,
)

compliance = completion.choices[0].message.parsed

# %%
compliance
# Out:
# ContentCompliance(is_violating=True, category=<Category.self_harm: 'self_harm'>, explanation_if_violating='The statement indicates an intention or desire to inflict self-harm, which is considered content that violates guidelines due to its potential to encourage or promote harmful behavior.')
